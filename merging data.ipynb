# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('sp500_full.csv')

# %%
data.head()
# Out:
#   ticker        Date  Adj Close  Close  High   Low  Open     Volume
# 0    AAL  2008-12-31   7.405228   7.73  7.87  7.48  7.48  4194100.0
# 1    AAL  2009-01-02   8.037499   8.39  8.48  7.67  7.73  5167000.0
# 2    AAL  2009-01-05   7.980019   8.33  8.39  7.96  8.38  3457100.0
# 3    AAL  2009-01-06   8.679349   9.06  9.21  8.13  8.15  5731000.0
# 4    AAL  2009-01-07   8.698509   9.08  9.47  8.66  8.66  5468900.0

# %%
data.shape
# Out:
# (1254420, 8)

# %%
data['ticker'].nunique()
# Out:
# 505

# %%
tickers = pd.read_csv('constituents_csv.csv')
tickers = tickers.rename(index = str, columns = {'Symbol': 'ticker'})

# %%
data = pd.merge(data, tickers, how = 'left', on = 'ticker')

# %%
tickers.head()
# Out:
#   ticker                 Name                  Sector
# 0    MMM           3M Company             Industrials
# 1    AOS      A.O. Smith Corp             Industrials
# 2    ABT  Abbott Laboratories             Health Care
# 3   ABBV          AbbVie Inc.             Health Care
# 4    ACN        Accenture plc  Information Technology

# %%
data.head()
# Out:
#   ticker        Date  Adj Close  Close  High   Low  Open     Volume  \
# 0    AAL  2008-12-31   7.405228   7.73  7.87  7.48  7.48  4194100.0
# 1    AAL  2009-01-02   8.037499   8.39  8.48  7.67  7.73  5167000.0
# 2    AAL  2009-01-05   7.980019   8.33  8.39  7.96  8.38  3457100.0
# 3    AAL  2009-01-06   8.679349   9.06  9.21  8.13  8.15  5731000.0
# 4    AAL  2009-01-07   8.698509   9.08  9.47  8.66  8.66  5468900.0
#
#                       Name       Sector
# 0  American Airlines Group  Industrials
# 1  American Airlines Group  Industrials
# 2  American Airlines Group  Industrials
# 3  American Airlines Group  Industrials
# 4  American Airlines Group  Industrials

# %%
data2 = data.dropna()

# %%
data2['ticker'].nunique()
# Out:
# 487

# %%
# Out:
#         ticker        Date  Adj Close      Close       High        Low  \
# 0          AAL  2008-12-31   7.405228   7.730000   7.870000   7.480000
# 1          AAL  2009-01-02   8.037499   8.390000   8.480000   7.670000
# 2          AAL  2009-01-05   7.980019   8.330000   8.390000   7.960000
# 3          AAL  2009-01-06   8.679349   9.060000   9.210000   8.130000
# 4          AAL  2009-01-07   8.698509   9.080000   9.470000   8.660000
# 5          AAL  2009-01-08   9.167923   9.570000   9.670000   8.620000
# 6          AAL  2009-01-09   8.621870   9.000000   9.380000   8.880000
# 7          AAL  2009-01-12   8.181195   8.540000   9.160000   8.270000
# 8          AAL  2009-01-13   7.922542   8.270000   8.660000   8.110000
# 9          AAL  2009-01-14   7.079513   7.390000   8.160000   7.250000
# 10         AAL  2009-01-15   7.232792   7.550000   9.700000   6.850000
# 11         AAL  2009-01-16   8.171617   8.530000   8.660000   7.750000
# ...

# %%
ticker_full = list(set(data['ticker']))
ticker_not_full = list(set(data2['ticker']))

# %%
result = list((Counter(ticker_full) - Counter(ticker_not_full)).elements())

# %%
result
# Out:
# ['WCG',
#  'JEF',
#  'JKHY',
#  'BF-B',
#  'TWTR',
#  'BRK-B',
#  'FLT',
#  'FTNT',
#  'CPRT',
#  'EVRG',
#  'ROL',
#  'ANET',
#  'BR',
#  'MSCI',
#  'LIN',
#  'KEYS',
#  'HFC',
#  'ABMD']

# %%
data.to_csv('for_cloud.csv', index = False)
